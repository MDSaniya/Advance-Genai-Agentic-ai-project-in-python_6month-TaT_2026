# %%
# Arithmetic operators
a = 5
b = 2
sum_res = a+b
diff_res = a-b
product_res = a*b
division_res = a/b

# Comparision operators
is_equal = a == b
is_not_equal = a != b
is_greater_than = a > b
is_less_than = a < b

# Logical operators
logical_and = (a > 0) and (b > 0)
logical_or = (a > 0) or (b > 0)
logical_not = not (a > 0)

print("Arithmetic Operators:")
print("Sum:", sum_res)
print("Difference:", diff_res)
print("product:", product_res)
print("Division:",division_res)

print("\nComparision Operators:")
print("Is Equal:", is_equal)
print("Is Not Equal:", is_not_equal)
print("Is Greater Than:", is_greater_than)
print("Is Less Than:", is_less_than)

print("\nLogical Operators:")
print("Logical AND:", logical_and)
print("Logical OR:",logical_or)
print("Logical NOT", logical_not)
# Out:
# Arithmetic Operators:
# Sum: 7
# Difference: 3
# product: 10
# Division: 2.5
#
# Comparision Operators:
# Is Equal: False
# Is Not Equal: True
# Is Greater Than: True
# Is Less Than: False
#
# Logical Operators:
# Logical AND: True
# Logical OR: True
# Logical NOT False

# %%
# Unary Operators


# Unary minus (-) operator
num = 10
res = -num
print("Unaru Minus Operator:", res)

# Unary plus (+) operator
res = +num
print("Unary plus Operator:",res)

# Logical NOT(!) operator
is_true = True
logical_not_res = not is_true
print("logical NOT Operator:", logical_not_res)
# Out:
# Unaru Minus Operator: -10
# Unary plus Operator: 10
# logical NOT Operator: False

# %%
# Binary Operator
# Binary addition (+) Operator
a = 5
b = 3
addition_res = a + b
print("Binary addition Operator:",addition_res)

#Binary Multiplication (*) operator
multiplication_res = a * b
print("Binary Multiplication Operator:", multiplication_res)

#Logical AND Operator
bitwise_and_res = a & b
print("Bitwise AND Operator:", bitwise_and_res)
# Out:
# Binary addition Operator: 8
# Binary Multiplication Operator: 15
# Bitwise AND Operator: 1

# %%
#Diffrentiating b/w == and is operator
list1 = [1,2,3]
list2 = [1,2,3]

# == compares values
res1 = list1 == list2

list3 = [1,2,3]
list4 = [1,2,3]

# is checks if obj refer to the same memory location
res2  = list3 is list4

print("Using == Operator:", res1)
print("Using is operator:",res2)
# Out:
# Using == Operator: True
# Using is operator: False

# %%
# Logical Operators
num1 = 5
num2 = 10
# and returns True if both condition are True
res1 = (num1 > 0) and (num2 > 0)

# Example with or operator 
num3 = -5
num4 = 10

# or returns True if at least one condition is True
res2 = (num3 > 0) or (num4 > 0)

# Example with not operator
flag = True

# not returns the opposite of the given condition
# flag returns False because flag is true

res3 = not flag

print("Using and operator:", res1)
print("Using or operator:", res2)
print("Using not Operator:", res3)
# Out:
# Using and operator: True
# Using or operator: True
# Using not Operator: False

# %%
# Bitwise Operators
# Example with bitwise AND operator
num1 = 5
num2 = 3

res_and = num1 & num2
res_or = num1 | num2
res_xor = num ^ num2
res_left_shift = num1 << 1
res_right_shift = num1 >> 1

print("Bitwise AND:", res_and)
print("Bitwise OR:", res_or)
print("Bitwise xor:", res_xor)
print("Left Shift:", res_left_shift)
print("Right Shift:", res_right_shift)
# Out:
# Bitwise AND: 1
# Bitwise OR: 7
# Bitwise xor: 9
# Left Shift: 10
# Right Shift: 2

# %%
# Using Membership Operators in Python
# Example with the 'in' operator
fruits = ['apple','banana', ' orange']

#Check if ' banana' is in the list
is_banana_in_list = 'banana' in fruits

#Check if 'grape' is in the list
is_grape_in_list = 'grape' in fruits

#Example with the 'not in' operator
#Check if 'watermelon' is not in the list
is_watermelon_not_in_list = 'watermelon' not in fruits

#Check if 'orange' is not in the list
is_orange_not_in_list = 'orange' not in fruits

print(" 'banana' in fruits:", is_banana_in_list)
print(" 'grape' in fruits:", is_grape_in_list)
print(" 'watermelon' in fruits:", is_watermelon_not_in_list)
print(" 'orange' in fruits:", is_orange_not_in_list)
# Out:
#  'banana' in fruits: True
#  'grape' in fruits: False
#  'watermelon' in fruits: True
#  'orange' in fruits: True

# %%
# Using identity operators in python
# Example with the 'is' operator
x = [1,2,3]
y = [1,2,3]
z = x

# Check if x and y refer to the same object
are_x_and_y_same = x is y

# Check if x and z refer to the same object
are_x_and_z_same = x is z

# Example with the 'is not' operator
# Check if x and  do not refer to the same object
are_x_and_y_not_same = x is not y

# Check if x and z do not refer to the same object
are_x_and_z_not_same = x is not z

print("x is y:", are_x_and_y_same)
print("x is z:", are_x_and_z_same)
print("x is not y:", are_x_and_y_not_same)
print("x is not z:", are_x_and_z_not_same)
# Out:
# x is y: False
# x is z: True
# x is not y: True
# x is not z: False

# %%
# Using the ternary conditional operator
temperature = 25
weather = "Sunny" if temperature > 20 else "Cloudy"

print("Weather today:", weather)
# Out:
# Weather today: Sunny

# %%
#Using comparison operators in python
x = 5
y = 10

result_lt = x < y
result_gt = x > y
result_gte = x >= y
result_lte = x <= y
result_ne = x != y
result_eq = x == y

print("x < y:", result_lt)
print("x > y:", result_gt)
print("x <= y:", result_lte)
print("x >= y:", result_gte)
print("x != y:", result_ne)
print("x == y:", result_eq)
# Out:
# x < y: True
# x > y: False
# x <= y: True
# x >= y: False
# x != y: True
# x == y: False

# %%
# Using the in keyword with strings and lists
string_exp = "python"
char_to_check = "t"

#Check if a character is present in the string
is_present = char_to_check in string_exp
print(f"is '{char_to_check}' presnt in '{string_exp}' ? {is_present}")

#Example with lists
list_exp = [1,2,3,4,5]
element_to_check = 3

#Check if an element is presnt in the list
is_present = element_to_check in list_exp
print(f"is {element_to_check} present in {list_exp} ? {is_present}")
# Out:
# is 't' presnt in 'python' ? True
# is 3 present in [1, 2, 3, 4, 5] ? True

# %%
# Uisng the slice operator with strings and lists
string_exp = "pythonprogramming"

#Extract a substring using slicing
substring = string_exp[6:16]
print("Substring:", substring)

#Example with lists
list_exp = [1,2,3,4,5,6,7,8,9]

#Extract a sublist using slicing
sublist = list_exp[2:7]
print("sublist:",sublist)
# Out:
# Substring: programmin
# sublist: [3, 4, 5, 6, 7]

# %%
# Using the ** operator for exponentiation
base = 2
exponent = 3

res = base ** exponent
print("Result:", res)
# Out:
# Result: 8

# %%
#Using the // operator for floor division
#It performs division and returns the largest integer less than or equal to the quotient 

dividend = 10
divisor = 3
res = dividend // divisor
print ("result:",res)
# Out:
# result: 3

# %%
# Uisng the += operator for add
num1 = 5
num1 += 3
print("Result:", num1)

# Using the += operator for multiplication
num2 = 4
num2 *= 2
print("Resullt:", num2)
# Out:
# Result: 8
# Resullt: 8

# %%
# Creating Tuple using ()
my_tuple = (1,2,3)
print("Tuple:", my_tuple)
# Out:
# Tuple: (1, 2, 3)

# %%
#using () for function calls and grouping expressions
res = (5+3)*2
print("Result:",res)
# Out:
# Result: 16
