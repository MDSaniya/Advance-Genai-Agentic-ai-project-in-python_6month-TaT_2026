# %%
import cv2

cap = cv2.VideoCapture(0)

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)

while True:
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) # we can change the colour from gray to any

    cv2.imshow('frame', gray)


    if cv2.waitKey(1) & 0xFF == ord('q') : #q to exit
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)

while True:
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB) # we can change the colour from gray to any

    cv2.imshow('frame', gray)


    if cv2.waitKey(1) & 0xFF == ord('q') : #q to exit
        break

cap.release()
cv2.destroyAllWindows()
