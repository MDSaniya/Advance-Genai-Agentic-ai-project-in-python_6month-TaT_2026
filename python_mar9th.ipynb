# %% [markdown]
# # Variable decleration in python
#
# syntax -- variable = value

# %%
nit = 1030
nit
# Out:
# 1030

# %%
1030 = nit
# Out:
#   Cell In[2], line 1
#     1030 = nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
#variable doesnot start with number so invalid and syntax error (user side error )
1nit = 10
1nit
# Out:
#   Cell In[5], line 2
#     1nit = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
#it is valid because it ends with number variable cannot start with number but can end with number
nit1 = 10
nit1
# Out:
# 10

# %%
#Invalid because we define in lower case we should call in lower case only - variables are case senstive
nit1 = 10
NIT1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #Invalid because we define in lower case we should call in lower case only - variables are case senstive
#       2 nit1 = 10
# ----> 3 NIT1
#
# NameError: name 'NIT1' is not defined

# %%
nit
# Out:
# 1030

# %%
nit1
# Out:
# 10

# %%
#invalid because special characters are not allowed
nit@ = 8
nit@
# Out:
#   Cell In[14], line 2
#     nit@ = 8
#          ^
# SyntaxError: invalid syntax

# %%
#Only underscore is allowed
nit_ = 32
nit_
# Out:
# 32

# %%
nit$ = 6
nit$
# Out:
#   Cell In[16], line 1
#     nit$ = 6
#        ^
# SyntaxError: invalid syntax

# %%
#Variables can start with underscore
_nit = 5
_nit
# Out:
# 5

# %%
#If we write underscore only then it stores previous value

_
# Out:
# 5

# %% [markdown]
# # KEYWORDS IN PYTHON

# %%
#only True False and None start with uppercase
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
# Reserver word or keywords cannot be declare as variable
# it is invalid because "for" is a keyword
for = 45
for
# Out:
#   Cell In[23], line 3
#     for = 45
#         ^
# SyntaxError: invalid syntax

# %%
#valid because "For" it is user define with upper case F
For = 5
For
# Out:
# 5

# %%
# keywords cannot define as a variable
if = 67
# Out:
#   Cell In[27], line 2
#     if = 67
#        ^
# SyntaxError: invalid syntax

# %%
else = 7
# Out:
#   Cell In[26], line 1
#     else = 7
#     ^
# SyntaxError: invalid syntax

# %%
true = 7
true
# Out:
# 7

# %%
a = true
a
# Out:
# 7
