# %% [markdown]
# # Variable declaration in python
# ## Variable = object = identifier
# ### variable(object) = value(datatype)

# %%
nit = 1030
nit
# Out:
# 1030

# %%
1030 = nit
# Out:
#   Cell In[2], line 1
#     1030 = nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1nit = 10
1nit
# Out:
#   Cell In[3], line 1
#     1nit = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 10
nit1
# Out:
# 10

# %%
nit  = 20
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 nit  = 20
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 20

# %%
a = 35
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 a = 35
# ----> 2 A
#
# NameError: name 'A' is not defined

# %%
nit@ = 8
nit@
# Out:
#   Cell In[8], line 1
#     nit@ = 8
#          ^
# SyntaxError: invalid syntax

# %%
nit_ = 32
nit_
# Out:
# 32

# %%
nit$ = 6
nit$
# Out:
#   Cell In[10], line 1
#     nit$ = 6
#        ^
# SyntaxError: invalid syntax

# %%
_nit = 5
_nit
# Out:
# 5

# %%
_
# Out:
# 5

# %%
_nit
# Out:
# 5

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
for = 25
for
# Out:
#   Cell In[19], line 1
#     for = 25
#         ^
# SyntaxError: invalid syntax

# %%
For = 24
For
# Out:
# 24

# %%
if = 67
# Out:
#   Cell In[21], line 1
#     if = 67
#        ^
# SyntaxError: invalid syntax

# %%
else = 7
# Out:
#   Cell In[22], line 1
#     else = 7
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Python variables Completed

# %% [markdown]
# # Python Datatype

# %%
i = 5
i
# Out:
# 5

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140707923534888

# %%
f = 110.45
f
# Out:
# 110.45

# %%
type(f)
# Out:
# float

# %%
gold_price = 14800.78
gold_price
# Out:
# 14800.78

# %%
type(gold_price)
# Out:
# float

# %%
10 + 5
10 - 5
10 * 5
# Out:
# 50

# %%
print(10 + 5)
print(10 - 5)
print(10 * 5)
# Out:
# 15
# 5
# 50

# %%
f1 = 2.4e1
f1
# Out:
# 24.0

# %%
type(f1)
# Out:
# float

# %%
f2 = 3.5e3
f2
# Out:
# 3500.0

# %%
f3 = 3.2E3
f3
# Out:
# 3200.0

# %% [markdown]
# # Boolean Value

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
True + False - False
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
False / True #float division
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
int(True)
# Out:
# 1

# %% [markdown]
# # Complex

# %%
c = 10 + 20j # 10 - real part & 20 imaginary part where j = square root of -1
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c = 10 + 20j
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0
