# %% [markdown]
# # Python Operator

# %% [markdown]
# ## Arithmetic Operator

# %%
x1,y1 = 10,5

# %%
x1 ^ y1
# Out:
# 15

# %%
x1 + y1
# Out:
# 15

# %%
x1 - y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1 // y1
# Out:
# 2

# %%
x1 %y1
# Out:
# 0

# %%
x1 ** y1
# Out:
# 100000

# %%
x2 = 3
y2 = 2
x2 ** y2
# Out:
# 9

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# # Assignment Operator

# %%
x=2

# %%
x = x + 2
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x *= 2
x
# Out:
# 24

# %%
x -= 2
x
# Out:
# -3

# %%
x /= 2
x
# Out:
# -1.5

# %%
x //= 2
x
# Out:
# -1.0

# %%
x *= 2
x
# Out:
# 48

# %%
a, b =5,6

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
x //= 2
x
# Out:
# 24

# %% [markdown]
# # Unary Operator

# %%
n = 7
n
# Out:
# 7

# %%
m = -(n)
m
# Out:
# -7

# %%
n
# Out:
# 7

# %%
-n
# Out:
# -7

# %% [markdown]
# # Relational Operator

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
b < a
# Out:
# False

# %%
a = b

# %%
a == b
# Out:
# True

# %%
c = 5
d = 7

# %%
c == d
# Out:
# False

# %%
c = d

# %%
print(c)
print(d)
# Out:
# 7
# 7

# %%
c == d
# Out:
# True

# %%
c != d
# Out:
# False

# %%
print(c)
print(d)
# Out:
# 7
# 7

# %%
c > d
# Out:
# False

# %%
c >= d
# Out:
# True

# %%
c < d
# Out:
# False

# %%
c <= d
# Out:
# True

# %% [markdown]
# # Logical Table

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 or b < 5
# Out:
# True

# %%
a < 8 or b > 5
# Out:
# True

# %%
print(a)
print(b)
# Out:
# 5
# 4

# %%
a < 8 and b < 2
# Out:
# False

# %%
a>8 or b<2
# Out:
# False

# %%
x = True
x
# Out:
# True

# %%
not x
# Out:
# False

# %%
-True
# Out:
# -1

# %%
-False
# Out:
# 0

# %%
10 + 3 * 2 -1
# Out:
# 15

# %%
10 + 3 * 2 - 1
# Out:
# 15

# %%
10 + 3 * (2-1)
# Out:
# 13

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 30

add=num1+num2
print(add)
# Out:
# 50
