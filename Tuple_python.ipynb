# %% [markdown]
# # TUPLE

# %%
t = ()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = (10,20,20)
t1
# Out:
# (10, 20, 20)

# %%
t1.count(10)
# Out:
# 1

# %%
t1.count(100)
# Out:
# 0

# %%
t1
# Out:
# (10, 20, 20)

# %%
t1.index(10)
# Out:
# 0

# %%
t1
# Out:
# (10, 20, 20)

# %%
t1[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t1[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
sbi = (1234,'cizps')

# %%
sbi
# Out:
# (1234, 'cizps')

# %%
sbi[0] = 456
sbi
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sbi[0] = 456
#       2 sbi
#
# TypeError: 'tuple' object does not support item assignment

# %%
sbi
# Out:
# (1234, 'cizps')

# %%
t1
# Out:
# (10, 20, 20)

# %%
t1*2
# Out:
# (10, 20, 20, 10, 20, 20)

# %% [markdown]
# ## Tuple Creation

# %%
tup1 = () #empty tuple

# %%
tup2 = (10,30,60) #tuple of int

# %%
tup3 = (10.66,30.55,60.67) # tuple of float

# %%
tup4 = ('one','two',"Three") # tuple of strings

# %%
tup5 = ('saniya',22,(50,100),(150,90)) # Nested tuples

# %%
tup6 = (100,'Saniya',17.765) # tuple of mixed data types

# %%
tup7 = ('Saniya',25,[50,100],[150,90],{'john','David'},(99,22,33))

# %%
len(tup7) # length of list
# Out:
# 6

# %% [markdown]
# ## Tuple Indexing

# %%
tup2[0] # Retrive first ele
# Out:
# 10

# %%
tup4[0]
# Out:
# 'one'

# %%
tup4[0][0] #Nested indexing - Access the first character of the first tuple ele
# Out:
# 'o'

# %%
tup4[-1] #last item of the tuple
# Out:
# 'Three'

# %%
tup5[-1]
# Out:
# (150, 90)

# %% [markdown]
# ## Tuple Slicing

# %%
mytuple = ('one','two','three','four','five','six','seven','eight')

# %%
mytuple[0:3] # return all items from 0th to 3rd index location excluding the item
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5]
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2] # return first two items
# Out:
# ('one', 'two')

# %%
mytuple[-3:] # return last three items
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[-2:]
# Out:
# ('seven', 'eight')

# %%
mytuple[-1]
# Out:
# 'eight'

# %%
mytuple[:] # return whole tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %% [markdown]
# ## Remove and Change Items

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple[0] # tuples are immutable which means we cant Delete tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 del mytuple[0] # tuples are immutable which means we cant Delete tuple items
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0] = 1 # Tuples are immutable which means we cnt CHANGE tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 mytuple[0] = 1 # Tuples are immutable which means we cnt CHANGE tuple items
#
# TypeError: 'tuple' object does not support item assignment

# %%
del mytuple # Deleting entire tuple object is possible
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 del mytuple # Deleting entire tuple object is possible
#
# NameError: name 'mytuple' is not defined

# %% [markdown]
# ## Loop Through a Tuple

# %%
mytuple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 mytuple
#
# NameError: name 'mytuple' is not defined

# %%
mytuple = ('one','two','three','four','five','six','seven','eight')

# %%
for i in mytuple:
     print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# ## Tuple Membership

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'one' in mytuple # Chcek if one exist in the list
# Out:
# True

# %%
'ten' in mytuple # check if ten exist in mytuple
# Out:
# False

# %%
if 'three' in mytuple:
    print('Three is present in the tuple')
else:
     print('Three is not present in the tuple')
# Out:
# Three is present in the tuple

# %%
if 'eleven' in mytuple:
    print('Eleven is present in the tuple')
else:
    print('Eleven  is not present in the tuple')
# Out:
# Eleven  is not present in the tuple

# %% [markdown]
# ## Index Position

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple.index('one') # Index of first ele equal to 'one'
# Out:
# 0

# %%
mytuple.index('five')
# Out:
# 4

# %%
mytuple1 = ('one','two','three','four','one','two','three')

# %%
mytuple1.index('one') # Index of first ele equal to one
# Out:
# 0

# %% [markdown]
# ## Sorting

# %%
mytuple2 = (43,56,66,87,9,23,76)

# %%
sorted(mytuple2) # Returns a new sorted list and doesnt change original tuple
# Out:
# [9, 23, 43, 56, 66, 76, 87]

# %%
sorted(mytuple2, reverse=True) # sort in descending order
# Out:
# [87, 76, 66, 56, 43, 23, 9]
