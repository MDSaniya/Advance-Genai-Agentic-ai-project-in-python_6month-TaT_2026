# %% [markdown]
# # WITHOUT USING MATPLOTLIB WE WORK WITH OPEN CV

# %%
import cv2

myimg = cv2.imread(r'C:\Users\saniy\OneDrive\Pictures\anime.jpg')

# %%
wrong_img = cv2.imread(r'C:\Users\saniy\OneDrive\Pictures\dog.jpg') #imread never gives an error even u dnt have img in the folder

# %%
type(wrong_img) #bcz we are not having an img with name dog

# %%
type(myimg)

# %%
import cv2

myimg = cv2.imread(r'C:\Users\saniy\OneDrive\Pictures\anime.jpg')

cv2.imshow('my image',myimg) #opened in another window with name my image, after closing the window wil get -1

cv2.waitKey() #the window popup will waits until a user dont close it 
# the problem with this is when ever image is created another window the user has to close it manually

# %%
import cv2

myimg = cv2.imread(r'C:\Users\saniy\OneDrive\Pictures\anime.jpg')

while True:

    cv2.imshow('my image',myimg)

    if cv2.waitKey(1) & 0xFF == 27 : #
        break

cv2.destroyAllWindows()
