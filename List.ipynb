# %% [markdown]
# # LIST DATASTRUCTURE

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l1 = [10,2.3,1+2j,True,'nit',[1,2,3]]
l1
# Out:
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
len(l1)
# Out:
# 6

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
print(id(l))
print(id(l1))
# Out:
# 2160846490048
# 2160846489600

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l2 = l.copy()
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 2160846490048
# 2160846489600
# 2160850501376

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
len(l2)
# Out:
# 6

# %%
l2.clear()

# %%
len(l2)
# Out:
# 0

# %%
l2
# Out:
# []

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l.count(10)
# Out:
# 2

# %%
l.count(20)
# Out:
# 1

# %%
l.count(50)
# Out:
# 1

# %%
l.count(100)
# Out:
# 0

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
a = [1,2,3]
b = [4,5,6]
a.extend(b)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l2 = []
l2
# Out:
# []

# %%
l2.extend(l)

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l2.extend(l1)

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50, 10]
# [10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10]

# %%
l[0]
# Out:
# 10

# %%
l[0] = 100

# %%
l
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
job = [5000]
job
# Out:
# [5000]

# %%
job[0]
# Out:
# 5000

# %%
job[0] = 10000

# %%
job
# Out:
# [10000]

# %%
l
# Out:
# [100, 20, 30, 40, 50, 10]

# %%
l[-2] = 500
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l.index(100)
# Out:
# 0

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l2.index(10)
# Out:
# 0

# %%
l
# Out:
# [100, 20, 30, 40, 500, 10]

# %%
l.insert(2,22)

# %%
l
# Out:
# [100, 20, 22, 22, 22, 25, 25, 25, 25, 25, 25, 25, 30, 40, 500, 10]

# %%
l.remove(22)

# %%
l
# Out:
# [100, 20, 22, 22, 25, 25, 25, 25, 25, 25, 25, 30, 40, 500, 10]

# %%
l.remove(22)
l
# Out:
# [100, 20, 22, 25, 25, 25, 25, 25, 25, 25, 30, 40, 500, 10]

# %%
l.pop(2)
# Out:
# 22

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), True, 'nit', [1, 2, 3]]

# %%
l2.pop()
# Out:
# [1, 2, 3]

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j), True, 'nit']

# %%
l2.pop()
# Out:
# 'nit'

# %%
l2.pop()
# Out:
# True

# %%
l2
# Out:
# [10, 20, 30, 40, 50, 10, 10, 2.3, (1+2j)]

# %%
l2.pop(2)
# Out:
# 30

# %%
l2
# Out:
# [10, 20, 40, 50, 10, 10, 2.3, (1+2j)]

# %%
l2.remove(40)

# %%
l2
# Out:
# [10, 20, 50, 10, 10, 2.3, (1+2j)]

# %%
l2.pop(4)
# Out:
# 10

# %%
l
# Out:
# [100, 20, 25, 25, 25, 25, 25, 25, 25, 30, 40, 500, 10]

# %%
l.reverse()

# %%
l
# Out:
# [10, 500, 40, 30, 25, 25, 25, 25, 25, 25, 25, 20, 100]

# %%
l.sort() #ascending order

# %%
l
# Out:
# [10, 20, 25, 25, 25, 25, 25, 25, 25, 30, 40, 100, 500]

# %%
l.sort(reverse=True)
l
# Out:
# [500, 100, 40, 30, 25, 25, 25, 25, 25, 25, 25, 20, 10]

# %%
l3 = [10,20,[2,3],3]

# %%
l3[2]=[2]
l3
# Out:
# [10, 20, [2], 3]

# %%
l
# Out:
# [500, 100, 40, 30, 25, 25, 25, 25, 25, 25, 25, 20, 10]

# %%
5000 in l
# Out:
# False

# %%
l
# Out:
# [500, 100, 40, 30, 25, 25, 25, 25, 25, 25, 25, 20, 10]

# %%
for i in l:
    print (i)
# Out:
# 500
# 100
# 40
# 30
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 20
# 10

# %% [markdown]
# # LIST

# %%
# List is an ordered sequence of items
# we can have diff data types under a list. E.g we can have int,float and string
# items in a same ist

# %% [markdown]
# ## List Creation

# %%
list1 = []

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 = [10,30,60]

# %%
list3 = [10.77,30.66,60.89]

# %%
list4 = ['one','two',"three"]

# %%
list5 = ['Asif',25,[50,100],[150,90]]

# %%
list6 = [100,'Asif',17.765]

# %%
list7 = ['Asif',25,[50,100],[150,90],{'john','David'}]

# %%
len(list6)
# Out:
# 3

# %% [markdown]
# ## List Indexing

# %%
list2[0] # retrive first ele of the list
# Out:
# 10

# %%
list4[0]
# Out:
# 'one'

# %%
list4[0][0] #Nested indexing - access the first character of the first ist ele
# Out:
# 'o'

# %%
list4[-1] #lat item of the list
# Out:
# 'three'

# %%
list5[-1] # last item of the list
# Out:
# [150, 90]

# %% [markdown]
# ## List Slicing

# %%
mylist = ['one','two','three','four','five','six','seven','eight']

# %%
mylist[0:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5]
# Out:
# ['three', 'four', 'five']

# %%
mylist[:3]
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2]
# Out:
# ['one', 'two']

# %%
mylist[-3:]
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:]
# Out:
# ['seven', 'eight']

# %%
mylist[-1]
# Out:
# 'eight'

# %%
mylist[:]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ## Add, Remove and Change Items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine')
mylist
# add an item to the end of the list
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'nine']

# %%
mylist.insert(9,'ten')
mylist
# add an item at index location 9
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine',
#  'ten']

# %%
mylist.insert(1,'ONE')
mylist
#add item at index location 1
# Out:
# ['one',
#  'ONE',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine',
#  'ten']

# %%
mylist.remove('ONE')
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine',
#  'ten']

# %%
mylist.pop()
mylist
#remove last item of the list
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine']

# %%
mylist.pop(8)
mylist
# remove item at index location 8
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'ten', 'nine']

# %%
del mylist[7]
mylist
# Remove item at index location 7
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'ten', 'nine']

# %%
# Change value of the string
mylist[0] = 1
mylist[1] = 2
mylist[2] = 3
mylist
# Out:
# [1, 2, 3, 'four', 'five', 'six', 'seven', 'ten', 'nine']

# %%
mylist.clear() 
mylist
# Empty list
# Out:
# []

# %%
del mylist
mylist
# Delete the whole list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 del mylist
# ----> 2 mylist
#       3 # Delete the whole list
#
# NameError: name 'mylist' is not defined

# %% [markdown]
# ## Copy List

# %%
mylist = ['one','two','three','four','five','six','seven','eight','nine','ten']

# %%
mylist1 = mylist #Create a new reference "mylist1"

# %%
id(mylist),id(mylist1) #The address of both mylist and mylist1 will be the same
# Out:
# (2125629522496, 2125629522496)

# %%
mylist2 = mylist.copy() # create a copy of the list

# %%
id(mylist2)
# Out:
# 2125629245760

# %%
mylist[0] = 1

# %%
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist1 # mylist1 will be also impacted as it is pointing to the same list
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist2 # Copy of list won't be impacted due to changes mode on the original list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %% [markdown]
# ## Join Lists

# %%
list1 = ['one','two','three','four']
list2 = ['five','six','seven','eight']

# %%
list3 = list1 + list2
list3
# join two lists by '+' operator
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2) #Append list2 with list1
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# ## List Membership

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1 # Check if 'one' exist in the list
# Out:
# True

# %%
'ten' in list1 # check if ten exist in the list
# Out:
# False

# %%
if 'three' in list1:
    print('Three is present in the list')
else:
    print('three is not present in the list')
# check if 'three' esixt in the list
# Out:
# Three is present in the list

# %%
if 'eleven' in list1:
    print('eleven is present in the list')
else:
    print('eleven is not present in the list')
# Out:
# eleven is not present in the list

# %% [markdown]
# ## Reverse and Sort List

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse()
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1 = list1[::-1]
list1
# Reverse the list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 list1 = list1[::-1]
#       2 list1
#       3 # Reverse the list
#
# TypeError: list[slice(None, None, -1)] is not a generic class

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort() # Sort list in ascending order
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort(reverse=True) # sort list in descending order
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
mylist4 = [88,65,33,21,11,98]
sorted(mylist4)
#returns a new sorted list and doesn't change original list
# Out:
# [11, 21, 33, 65, 88, 98]

# %%
mylist4
# Out:
# [88, 65, 33, 21, 11, 98]

# %% [markdown]
# ## Loop through a list

# %%
list1 = ['one','two','three','four','five','six','seven','eight']

# %%
for i in list1:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(list1):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# ## Count

# %%
list10 = ['one','two','three','four','one','two','three']

# %%
list10.count('one')
# Out:
# 2

# %%
list10.count('two')
# Out:
# 2

# %%
list10.count('four')
# Out:
# 1

# %% [markdown]
# ## All / Any

# %%
#The all() method returns:
# True- if all elements in a list are true
# False - if any element in a list is false
#The any() function returns true if any element in the list is True. If not, any() returns False

# %%
L1 = [1,2,3,4,0]

# %%
all(L1) # Will return false as one value is false (value 0)
# Out:
# False

# %%
any(L1) # will return true as we have items in the list with true value
# Out:
# True

# %%
L2 = [1,2,3,4,True,False]

# %%
all(L2)
# Out:
# False

# %%
any(L2)
# Out:
# True

# %%
L3 = [1,2,3,True]

# %%
all(L3)
# Out:
# True
