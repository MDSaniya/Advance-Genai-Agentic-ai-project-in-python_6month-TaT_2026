# %% [markdown]
# # PRINT() Statement

# %%
a = 10
b = 20
a
b
# Out:
# 20

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 30
add = num1 + num2
print(add)
# Out:
# 50

# %% [markdown]
# ## Print Result with String

# %%
num1 = 20
num2 = 30
add = num1 + num2
print('The addition of',num1,'and',num2,'is=',add)
# Out:
# The addition of 20 and 30 is= 50

# %%
name = 'python'
age = 20
city = 'hyd'

# %%
print('My name is',name,'and i am',age,'years old form',city)
# Out:
# My name is python and i am 20 years old form hyd

# %%
num1 = 20
num2 = 30
add = num1+num2
print('The addition of {} and {} is = {}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is = 50

# %%
name = 'python'
age = 20
city = 'hyd'

# %%
print('hello my name is {}, and i am {} years old form{}'.format (name,age,city))
# Out:
# hello my name is python, and i am 20 years old formhyd

# %%
num1 = 100
num2 = 25
num3 = 333
avg = (num1+num2+num3)/3
avg1 = round((num1+num2+num3)/3,2)
print('The average of {},{}, and {} is = {} or {}'. format(num1,num2,num3,avg,avg1))
# Out:
# The average of 100,25, and 333 is = 152.66666666666666 or 152.67

# %%
round(avg,2)
# Out:
# 152.67

# %%
num1 = 20
num2 = 30
add = num1 + num2
print(f'The addition of {num1} and {num2} is = {add}')
# Out:
# The addition of 20 and 30 is = 50

# %%
name = 'python'
age = 20
city = 'hyd'

# %%
print(f'hello my name is {name}, and i am {age} year old, from {city}.')
# Out:
# hello my name is python, and i am 20 year old, from hyd.

# %%
num1 = 100
num2 = 25
num3 = 333
avg = round((num1+num2+num3)/3,2)

# %%
print(f'The average of {num1}, {num2} and {num3} is = {avg}')
# Out:
# The average of 100, 25 and 333 is = 152.67

# %%
num1 = 10
num2 = 20
add = num1 + num2
print('The addition of',num1,'and',num2,'is=',add)
print('The addition of {} and {} is = {}'.format(num1,num2,add))
print(f'The addition of {num1} and {num2} is = {add}')
# Out:
# The addition of 10 and 20 is= 30
# The addition of 10 and 20 is = 30
# The addition of 10 and 20 is = 30

# %% [markdown]
# ## End Statement

# %%
print('hello')
print('good morning')
# Out:
# hello
# good morning

# %%
print('hello',end=' ')
print('world good day')
#Here we will use end statement that joint line from end of one string to 
#string of other string
# Out:
# hello world good day

# %% [markdown]
# # Seprator

# %%
print('hello','hi','how are you',sep='--->')
# Out:
# hello--->hi--->how are you

# %%
print('hello','hi','how are you',sep='&')
# Out:
# hello&hi&how are you

# %%
print('hello','hai','how are you',sep=' ')
# Out:
# hello hai how are you

# %%
print(3,'.')
# Out:
# 3 .

# %%
print(3,'.',sep='')
# Out:
# 3.

# %%
print(1,2,end=' ')
print(3,'.',sep='')
# Out:
# 1 2 3.

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
x = round(math.sqrt(25))
x
# Out:
# 5

# %%
math.floor(3.8)
# Out:
# 3

# %%
math.ceil(3.8)
# Out:
# 4

# %%
pow(3,2)
# Out:
# 9

# %%
math.pi
# Out:
# 3.141592653589793

# %%
pi = 3.17
pi
# Out:
# 3.17

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
import math as m

# %%
m.sqrt(49)
# Out:
# 7.0

# %%
from math import sqrt, pow
print(pow(2,3))
print(m.sqrt(10))
# Out:
# 8.0
# 3.1622776601683795

# %%
print(math.e)
# Out:
# 2.718281828459045

# %% [markdown]
# # Input()

# %%
x = input()
y = input()
z = x + y
print(z)
