# %% [markdown]
# # INTRODUCTION TO OPENCV & IMAGE PROCESSING

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/44.0 MB ? eta -:--:--
#     --------------------------------------- 0.8/44.0 MB 2.8 MB/s eta 0:00:16
#    - -------------------------------------- 1.3/44.0 MB 2.5 MB/s eta 0:00:17
#    - -------------------------------------- 2.1/44.0 MB 3.0 MB/s eta 0:00:15
#    -- ------------------------------------- 3.1/44.0 MB 3.4 MB/s eta 0:00:13
#    --- ------------------------------------ 3.9/44.0 MB 3.6 MB/s eta 0:00:12
#    ---- ----------------------------------- 5.2/44.0 MB 3.9 MB/s eta 0:00:10
#    ----- ---------------------------------- 6.3/44.0 MB 4.1 MB/s eta 0:00:10
#    ------ --------------------------------- 7.6/44.0 MB 4.4 MB/s eta 0:00:09
#    -------- ------------------------------- 9.2/44.0 MB 4.7 MB/s eta 0:00:08
#    --------- ------------------------------ 10.5/44.0 MB 4.9 MB/s eta 0:00:07
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\WORK-DONE-DSNI\workshop\cat.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (893, 1280, 3)

# %%
plt.imshow(img)

# %%
img
# Out:
# array([[[33, 57, 45],
#         [29, 53, 41],
#         [28, 49, 40],
#         ...,
#         [25, 25, 25],
#         [25, 25, 25],
#         [26, 26, 26]],
#
#        [[28, 52, 40],
#         [26, 50, 38],
#         [26, 47, 38],
#         ...,
#         [26, 26, 26],
#         [26, 26, 26],
#         [27, 27, 27]],
#
#        [[30, 52, 40],
#         [28, 50, 38],
#         [26, 48, 36],
#         ...,
#         [23, 26, 24],
#         [23, 26, 24],
#         [23, 26, 24]],
#
#        ...,
#
#        [[41, 85, 79],
#         [43, 87, 81],
#         [45, 87, 80],
#         ...,
#         [26, 26, 26],
#         [26, 26, 26],
#         [26, 26, 26]],
#
#        [[42, 84, 83],
#         [44, 87, 84],
#         [47, 87, 82],
#         ...,
#         [26, 26, 26],
#         [26, 26, 26],
#         [26, 26, 26]],
#
#        [[43, 84, 86],
#         [45, 86, 88],
#         [47, 86, 84],
#         ...,
#         [26, 26, 26],
#         [26, 26, 26],
# ...

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
fix_img.shape
# Out:
# (893, 1280, 3)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\WORK-DONE-DSNI\workshop\cat.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (893, 1280)

# %%
img_gray
# Out:
# array([[51, 47, 44, ..., 25, 25, 26],
#        [46, 44, 42, ..., 26, 26, 27],
#        [46, 44, 42, ..., 25, 25, 25],
#        ...,
#        [78, 80, 80, ..., 26, 26, 26],
#        [79, 81, 81, ..., 26, 26, 26],
#        [80, 82, 81, ..., 26, 26, 26]], shape=(893, 1280), dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
plt.imshow(img_gray, cmap='Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (893, 1280, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(446,640)) #resizing the img with half of the original values

# %%
fix_img_1.shape
# Out:
# (640, 446, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
fix_img_2
# Out:
# array([[[41, 53, 29],
#         [39, 48, 27],
#         [35, 44, 23],
#         ...,
#         [27, 27, 25],
#         [26, 26, 26],
#         [26, 26, 26]],
#
#        [[40, 52, 30],
#         [36, 48, 26],
#         [32, 44, 24],
#         ...,
#         [26, 28, 25],
#         [24, 26, 23],
#         [24, 26, 23]],
#
#        [[40, 53, 33],
#         [34, 47, 27],
#         [31, 44, 24],
#         ...,
#         [26, 31, 27],
#         [25, 30, 24],
#         [29, 34, 28]],
#
#        ...,
#
#        [[73, 89, 40],
#         [68, 88, 40],
#         [65, 88, 44],
#         ...,
#         [28, 28, 28],
#         [26, 26, 26],
#         [27, 27, 27]],
#
#        [[77, 87, 42],
#         [74, 87, 43],
#         [69, 87, 46],
#         ...,
#         [26, 26, 26],
#         [26, 26, 26],
#         [26, 26, 26]],
#
#        [[82, 86, 43],
#         [78, 86, 45],
#         [71, 86, 48],
#         ...,
#         [26, 26, 26],
#         [26, 26, 26],
# ...

# %%
plt.imshow(fix_img_2)

# %%
img3 = cv2.flip(fix_img_2,0) #flipping tthe img
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2,1) #flipping tthe img
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2,2) #flipping tthe img
plt.imshow(img3)

# %%
img3 = cv2.flip(fix_img_2,3) #flipping tthe img
plt.imshow(img3)

# %%
cv2.imwrite('new genai image.jpg',img3) #saving the image
# Out:
# True

# %%
pwd #saved image path
# Out:
# 'C:\\Users\\saniy'
